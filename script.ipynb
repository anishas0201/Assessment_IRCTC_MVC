-- %% [markdown]
-- # [MVCWebAssessment]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [MVCWebAssessment]    Script Date: 12/13/2023 12:18:05 PM ******/
CREATE DATABASE [MVCWebAssessment]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'MVCWebAssessment', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\MVCWebAssessment.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'MVCWebAssessment_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\MVCWebAssessment_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [MVCWebAssessment] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [MVCWebAssessment].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [MVCWebAssessment] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET ARITHABORT OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [MVCWebAssessment] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [MVCWebAssessment] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET  DISABLE_BROKER 
GO
ALTER DATABASE [MVCWebAssessment] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [MVCWebAssessment] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [MVCWebAssessment] SET  MULTI_USER 
GO
ALTER DATABASE [MVCWebAssessment] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [MVCWebAssessment] SET DB_CHAINING OFF 
GO
ALTER DATABASE [MVCWebAssessment] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [MVCWebAssessment] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [MVCWebAssessment] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [MVCWebAssessment] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [MVCWebAssessment] SET QUERY_STORE = ON
GO
ALTER DATABASE [MVCWebAssessment] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Student]

-- %%
USE [MVCWebAssessment]
GO

-- %%
/****** Object:  Table [dbo].[Student]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Student](
	[Name] [varchar](100) NULL,
	[DOB] [varchar](100) NULL,
	[Age] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_AdmissionFormData]

-- %%
/****** Object:  Table [dbo].[tbl_AdmissionFormData]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_AdmissionFormData](
	[AdmissionId] [int] IDENTITY(1,1) NOT NULL,
	[CollegeName] [nvarchar](50) NULL,
	[StudentName] [nvarchar](50) NULL,
	[BranchName] [nvarchar](50) NULL,
	[RoleDesignation] [nvarchar](50) NULL,
	[AdmissionDate] [date] NULL,
	[CollegeFees] [int] NULL,
	[IsPaymentDone] [bit] NULL,
	[IsActive] [bit] NULL,
 CONSTRAINT [PK_tbl_AdmissionFormData] PRIMARY KEY CLUSTERED 
(
	[AdmissionId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_DepartmentMaster]

-- %%
/****** Object:  Table [dbo].[tbl_DepartmentMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_DepartmentMaster](
	[BranchId] [int] IDENTITY(1,1) NOT NULL,
	[BranchName] [nvarchar](50) NULL,
	[HODName] [nvarchar](50) NULL,
	[CreatedDate] [date] NULL,
	[IsActive] [bit] NULL,
 CONSTRAINT [PK_tbl_DepartmentMaster] PRIMARY KEY CLUSTERED 
(
	[BranchId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_DepartmentsTable]

-- %%
/****** Object:  Table [dbo].[tbl_DepartmentsTable]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_DepartmentsTable](
	[Depno] [int] NOT NULL,
	[Dname] [varchar](50) NOT NULL,
	[Loc] [varchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_EmployeesTable]

-- %%
/****** Object:  Table [dbo].[tbl_EmployeesTable]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_EmployeesTable](
	[Empno] [int] NOT NULL,
	[Ename] [varchar](50) NOT NULL,
	[Job] [varchar](50) NOT NULL,
	[Salary] [int] NOT NULL,
	[Deptno] [int] NOT NULL,
 CONSTRAINT [PK_EmployeeTbl] PRIMARY KEY CLUSTERED 
(
	[Empno] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_EmpProjectTasks]

-- %%
/****** Object:  Table [dbo].[tbl_EmpProjectTasks]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_EmpProjectTasks](
	[Project_ID] [int] NOT NULL,
	[Empno] [int] NOT NULL,
	[Start_Date] [date] NOT NULL,
	[End_Date] [date] NOT NULL,
	[Task] [varchar](50) NOT NULL,
	[Status] [varchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_ExcelSheet]

-- %%
/****** Object:  Table [dbo].[tbl_ExcelSheet]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_ExcelSheet](
	[S_No] [int] NOT NULL,
	[First_Name] [nvarchar](50) NULL,
	[Last_Name] [nvarchar](50) NULL,
	[Gender] [nvarchar](50) NULL,
	[Country] [nvarchar](50) NULL,
	[Age] [int] NULL,
	[BirthDay] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_IRCTC_ConfirmTicket]

-- %%
/****** Object:  Table [dbo].[tbl_IRCTC_ConfirmTicket]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_IRCTC_ConfirmTicket](
	[ticketId] [int] IDENTITY(1,1) NOT NULL,
	[trainName] [nvarchar](50) NULL,
	[trainNumber] [nvarchar](50) NULL,
	[emailId] [nvarchar](50) NULL,
	[departureDate] [date] NULL,
	[ticketFare] [int] NULL,
 CONSTRAINT [PK_tbl_IRCTC_ConfirmTicket] PRIMARY KEY CLUSTERED 
(
	[ticketId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_IRCTC_Registration]

-- %%
/****** Object:  Table [dbo].[tbl_IRCTC_Registration]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_IRCTC_Registration](
	[registrationId] [int] IDENTITY(1,1) NOT NULL,
	[fullName] [nvarchar](50) NULL,
	[emailId] [nvarchar](50) NULL,
	[encryptedPassword] [nvarchar](50) NULL,
	[decryptedPassword] [nvarchar](50) NULL,
	[userType] [nvarchar](50) NULL,
 CONSTRAINT [PK_tbl_IRCTC_Registration] PRIMARY KEY CLUSTERED 
(
	[registrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_IRCTC_TrainMaster]

-- %%
/****** Object:  Table [dbo].[tbl_IRCTC_TrainMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_IRCTC_TrainMaster](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[trainName] [nvarchar](50) NULL,
	[trainNumber] [int] NULL,
	[fromPlace] [nvarchar](50) NULL,
	[toDestination] [nvarchar](50) NULL,
	[seatAvailability] [bit] NULL,
 CONSTRAINT [PK_tbl_IRCTC_TrainMaster] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_ProjectsTable]

-- %%
/****** Object:  Table [dbo].[tbl_ProjectsTable]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_ProjectsTable](
	[Project_ID] [int] NOT NULL,
	[Descr] [varchar](50) NOT NULL,
	[Start_Date] [date] NOT NULL,
	[Planned_End_Date] [date] NOT NULL,
	[Actual_End_date] [date] NULL,
	[Budget] [int] NOT NULL,
	[Client_ID] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_RoleMaster]

-- %%
/****** Object:  Table [dbo].[tbl_RoleMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_RoleMaster](
	[RoleId] [int] IDENTITY(1,1) NOT NULL,
	[RoleName] [nvarchar](50) NULL,
	[RoleDesignation] [nvarchar](50) NULL,
	[CreatedDate] [date] NULL,
	[IsActive] [bit] NULL,
 CONSTRAINT [PK_tbl_RoleMaster] PRIMARY KEY CLUSTERED 
(
	[RoleId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_SignUp]

-- %%
/****** Object:  Table [dbo].[tbl_SignUp]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_SignUp](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NULL,
	[UserId] [int] NULL,
	[encryptedPassword] [nvarchar](50) NULL,
	[decryptedPassword] [nvarchar](50) NULL,
 CONSTRAINT [PK_tbl_SignUp] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_StudentMaster]

-- %%
/****** Object:  Table [dbo].[tbl_StudentMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_StudentMaster](
	[StudentId] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [nvarchar](50) NULL,
	[LastName] [nvarchar](50) NULL,
	[Session] [nvarchar](50) NULL,
	[Email] [nvarchar](50) NULL,
	[ContactNo] [int] NULL,
	[CreatedDate] [date] NULL,
	[IsActive] [bit] NULL,
	[IsDeleted] [bit] NULL,
 CONSTRAINT [PK_tbl_StudentMaster] PRIMARY KEY CLUSTERED 
(
	[StudentId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ImportExcelData]

-- %%
/****** Object:  StoredProcedure [dbo].[ImportExcelData]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ImportExcelData]
    @FilePath NVARCHAR(255)
AS
BEGIN
    -- Check if the table exists, and if not, create it
    IF NOT EXISTS (SELECT 1 FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_NAME = 'tbl_ExcelSheet')
    BEGIN
        CREATE TABLE tbl_ExcelSheet
        (
            [S.No] INT,
            [First Name] NVARCHAR(50),
            [Last Name] NVARCHAR(50),
            [Gender] NVARCHAR(50),
            [Country] NVARCHAR(50),
            [Age] INT,
            [BirthDay] DATE
            -- Add more columns as needed
        );
    END;

    -- Insert data from the Excel file into the table
    DECLARE @SqlQuery NVARCHAR(MAX);
    SET @SqlQuery = 'INSERT INTO tbl_ExcelSheet ([S.No], [First Name], [Last Name], [Gender], [Country], [Age], [BirthDay]) ' +
                    'SELECT [S.No], [First Name], [Last Name], [Gender], [Country], [Age], [BirthDay] ' +
                    'FROM OPENROWSET(''Microsoft.ACE.OLEDB.12.0'', ''Excel 12.0;Database=' + @FilePath + ';HDR=YES;'', ''SELECT * FROM [Sheet1$]'')';

    EXEC sp_executesql @SqlQuery;

    -- Optional: Drop the table if you want to clear it after importing
    -- DROP TABLE tbl_ExcelSheet;
END
GO

-- %% [markdown]
-- # [dbo].[sp_delete_CollegeDetailById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_delete_CollegeDetailById]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_delete_CollegeDetailById]
    @AdmissionId int
AS
BEGIN
    DELETE FROM [tbl_AdmissionFormData] WHERE [AdmissionId] = @AdmissionId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_delete_DepartmentById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_delete_DepartmentById]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_delete_DepartmentById]
    @BranchId int
AS
BEGIN
    DELETE FROM [tbl_DepartmentMaster] WHERE [BranchId] = @BranchId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_delete_RoleById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_delete_RoleById]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_delete_RoleById]
    @RoleId int
AS
BEGIN
    DELETE FROM [tbl_RoleMaster] WHERE [RoleId] = @RoleId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_delete_StudentById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_delete_StudentById]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_delete_StudentById]
    @StudentId int
AS
BEGIN
    DELETE FROM [tbl_StudentMaster] WHERE [StudentId] = @StudentId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_get_CollegeDetailsbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_get_CollegeDetailsbyId]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_get_CollegeDetailsbyId]
    @AdmissionId INT
AS
BEGIN
    SELECT
        ad.AdmissionId,
        ad.CollegeName,
        S.FirstName AS StudentName,
        D.BranchName,
        R.RoleDesignation,
        ad.AdmissionDate,
        ad.CollegeFees,
        ad.IsPaymentDone,
        ad.IsActive
    FROM
        tbl_AdmissionFormData ad
    INNER JOIN
        tbl_DepartmentMaster D ON D.BranchId = ad.BranchName
    INNER JOIN
        tbl_RoleMaster R ON R.RoleId = ad.RoleDesignation
    INNER JOIN
        tbl_StudentMaster S ON S.StudentId = ad.StudentName
    WHERE
        ad.AdmissionId = @AdmissionId;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_get_DepartmentbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_get_DepartmentbyId]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_get_DepartmentbyId]
    @BranchId int
AS
BEGIN
    SELECT * FROM tbl_DepartmentMaster WHERE [BranchId] = @BranchId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_get_RolebyId]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_get_RolebyId]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_get_RolebyId]
    @RoleId int
AS
BEGIN
    SELECT * FROM tbl_RoleMaster WHERE [RoleId] = @RoleId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_get_StudentbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_get_StudentbyId]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_get_StudentbyId]
    @StudentId int
AS
BEGIN
    SELECT * FROM tbl_StudentMaster WHERE [StudentId] = @StudentId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_GetFormList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetFormList]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_GetFormList]
AS
BEGIN
    SELECT
        ad.AdmissionId,
        ad.CollegeName,
        S.FirstName , 
        D.BranchName ,
        R.RoleDesignation ,
        ad.AdmissionDate,
        ad.CollegeFees,
        ad.IsPaymentDone,
        ad.IsActive
    FROM
        tbl_AdmissionFormData ad
    INNER JOIN
        tbl_DepartmentMaster D ON D.BranchId = ad.BranchName
    INNER JOIN
        tbl_RoleMaster R ON R.RoleId = ad.RoleDesignation
    INNER JOIN
        tbl_StudentMaster S ON S.StudentId = ad.StudentName
END;
GO

-- %% [markdown]
-- # [dbo].[sp_GetTicketList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetTicketList]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_GetTicketList]
AS
BEGIN
    SELECT
        ad.ticketId,
        D.trainName,      
        ad.trainNumber,
        ad.emailId,
        ad.departureDate,
        ad.ticketFare
       
    FROM
        tbl_IRCTC_ConfirmTicket ad
     INNER JOIN
        tbl_IRCTC_TrainMaster D ON D.Id = ad.trainName 
    
END;
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_delete_TainById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_delete_TainById]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_IRCTC_delete_TainById]
    @Id int
AS
BEGIN
    DELETE FROM [tbl_IRCTC_TrainMaster] WHERE [Id] = @Id;
END
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_get_TrainbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_get_TrainbyId]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_IRCTC_get_TrainbyId]
    @Id int
AS
BEGIN
    SELECT * FROM tbl_IRCTC_TrainMaster WHERE [Id] = @Id;
END
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_GetTrainNumber]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_GetTrainNumber]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_IRCTC_GetTrainNumber]
    @trainName NVARCHAR(50)
AS
BEGIN
    SELECT Id, trainName, trainNumber
    FROM tbl_IRCTC_TrainMaster
    WHERE trainName = @TrainName;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_SaveTicket]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_SaveTicket]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_IRCTC_SaveTicket]
    @trainName NVARCHAR(50),
    @trainNumber NVARCHAR(50),
    @emailId NVARCHAR(50),
    @departureDate DATE,
    @ticketFare INT
AS
BEGIN
   

    INSERT INTO tbl_IRCTC_ConfirmTicket (trainName, trainNumber, emailId, departureDate, ticketFare)
    VALUES (@trainName, @trainNumber, @emailId, @departureDate, @ticketFare);


END;
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_SignUp]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_SignUp]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_IRCTC_SignUp]

@fullName nvarchar(50),

@emailId nvarchar(50),

@encryptedPassword nvarchar(50),

@decryptedPassword nvarchar(50),
@userType nvarchar(50)

AS

BEGIN

	insert into tbl_IRCTC_Registration(fullName,emailId,encryptedPassword,decryptedPassword,userType)

	values (@fullName,@emailId,@encryptedPassword,@decryptedPassword,@userType);

END
GO

-- %% [markdown]
-- # [dbo].[sp_IRCTC_Update_TrainDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_IRCTC_Update_TrainDetails]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[sp_IRCTC_Update_TrainDetails]
     @Id int,
   
	@trainName nvarchar(50),
	@trainNumber int,	 
	@fromPlace nvarchar(50),
	@toDestination nvarchar(50),
	@seatAvailability bit  

	
    
AS
BEGIN
    UPDATE tbl_IRCTC_TrainMaster
    SET 
        trainName = @trainName,
        trainNumber = @trainNumber,
		fromPlace = @fromPlace,
		toDestination = @toDestination,
		seatAvailability = @seatAvailability
       
       
    WHERE 
        Id = @Id
END
GO

-- %% [markdown]
-- # [dbo].[sp_SaveDepartmentUser]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveDepartmentUser]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_SaveDepartmentUser]
   
    @BranchName NVARCHAR(50),
    @HODName NVARCHAR(50),
    @CreatedDate DATE,
    @IsActive BIT
AS
BEGIN
    INSERT INTO tbl_DepartmentMaster ( BranchName, HODName, CreatedDate, IsActive)
    VALUES ( @BranchName, @HODName, @CreatedDate, @IsActive);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_SaveForm]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveForm]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_SaveForm]
   
    @CollegeName NVARCHAR(50),
    @StudentName NVARCHAR(50),
	   @BranchName NVARCHAR(50),
    @RoleDesignation NVARCHAR(50),
    @AdmissionDate DATE,
	@CollegeFees int,
	@IsPaymentDone bit,
    @IsActive BIT
AS
BEGIN
    INSERT INTO tbl_AdmissionFormData ( CollegeName, StudentName, BranchName, RoleDesignation, AdmissionDate, CollegeFees, IsPaymentDone, IsActive)
    VALUES ( @CollegeName, @StudentName,@BranchName,@RoleDesignation, @AdmissionDate,@CollegeFees,@IsPaymentDone, @IsActive);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_SaveRoleUser]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveRoleUser]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_SaveRoleUser]
   
    @RoleName NVARCHAR(50),
    @RoleDesignation NVARCHAR(50),
    @CreatedDate DATE,
    @IsActive BIT
AS
BEGIN
    INSERT INTO tbl_RoleMaster ( RoleName, RoleDesignation, CreatedDate, IsActive)
    VALUES ( @RoleName, @RoleDesignation, @CreatedDate, @IsActive);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_SaveStudentUser]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveStudentUser]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_SaveStudentUser]
    @FirstName NVARCHAR(50),
    @LastName NVARCHAR(50),
    @Session NVARCHAR(50),
    @Email NVARCHAR(50),
    @ContactNo INT,
    @CreatedDate DATE,
    @IsActive BIT,
    @IsDeleted BIT
AS
BEGIN
    INSERT INTO tbl_StudentMaster(FirstName, LastName, Session, Email, ContactNo, CreatedDate, IsActive, IsDeleted)
    VALUES (@FirstName, @LastName, @Session, @Email, @ContactNo, @CreatedDate, @IsActive, @IsDeleted);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_saveTrainDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_saveTrainDetails]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_saveTrainDetails]
    @trainName NVARCHAR(50),
    @trainNumber INT,
    @fromPlace NVARCHAR(50),
    @toDestination NVARCHAR(50),
    @seatAvailability BIT
AS
BEGIN
    

    INSERT INTO tbl_IRCTC_TrainMaster (trainName, trainNumber, fromPlace, toDestination, seatAvailability)
    VALUES (@trainName, @trainNumber, @fromPlace, @toDestination, @seatAvailability);

   

END;
GO

-- %% [markdown]
-- # [dbo].[sp_SearchByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SearchByDate]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_SearchByDate]
    @FromDate DATE,
    @ToDate DATE
AS
BEGIN
    SELECT
        ad.AdmissionId,
        ad.CollegeName,
        S.FirstName, 
        D.BranchName,
        R.RoleDesignation,
        ad.AdmissionDate,
        ad.CollegeFees,
        ad.IsPaymentDone,
        ad.IsActive
    FROM
        tbl_AdmissionFormData ad
    INNER JOIN
        tbl_DepartmentMaster D ON D.BranchId = ad.BranchName
    INNER JOIN
        tbl_RoleMaster R ON R.RoleId = ad.RoleDesignation
    INNER JOIN
        tbl_StudentMaster S ON S.StudentId = ad.StudentName
    WHERE
        ad.AdmissionDate BETWEEN @FromDate AND @ToDate;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_SignUp]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SignUp]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_SignUp]

@Name nvarchar(50),

@UserId int,

@encryptedPassword nvarchar(50),

@decryptedPassword nvarchar(50)

AS

BEGIN

	insert into tbl_SignUp(Name,UserId,encryptedPassword,decryptedPassword)

	values (@name,@userId,@encryptedPassword,@decryptedPassword);

END
GO

-- %% [markdown]
-- # [dbo].[sp_Update_CollegeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Update_CollegeDetails]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_Update_CollegeDetails]
    @AdmissionId INT,
    @CollegeName NVARCHAR(50),
    @StudentName NVARCHAR(50),
    @BranchName NVARCHAR(50),
    @RoleDesignation NVARCHAR(50),
    @AdmissionDate DATE,
    @CollegeFees INT,
    @IsPaymentDone BIT,
    @IsActive BIT
AS
BEGIN
    UPDATE [dbo].[tbl_AdmissionFormData]
    SET
        [CollegeName] = @CollegeName,
        [StudentName] = @StudentName,
        [BranchName] = @BranchName,
        [RoleDesignation] = @RoleDesignation,
        [AdmissionDate] = @AdmissionDate,
        [CollegeFees] = @CollegeFees,
        [IsPaymentDone] = @IsPaymentDone,
        [IsActive] = @IsActive
    WHERE
        [AdmissionId] = @AdmissionId;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_Update_DepartmentMaster]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Update_DepartmentMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[sp_Update_DepartmentMaster]
@BranchId int,
   
	@BranchName nvarchar(50),
	@HODName nvarchar(50),
	@CreatedDate date,
	@IsActive bit
	
    
AS
BEGIN
    UPDATE tbl_DepartmentMaster
    SET 
        BranchName = @BranchName,
        HODName = @HODName,
        CreatedDate = @CreatedDate,
        IsActive = @IsActive
       
    WHERE 
        BranchId = @BranchId
END
GO

-- %% [markdown]
-- # [dbo].[sp_Update_RoleMaster]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Update_RoleMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[sp_Update_RoleMaster]
@RoleId int,
   
	@RoleName nvarchar(50),
	@RoleDesignation nvarchar(50),
	@CreatedDate date,
	@IsActive bit
	
    
AS
BEGIN
    UPDATE tbl_RoleMaster
    SET 
        RoleName = @RoleName,
        RoleDesignation = @RoleDesignation,
        CreatedDate = @CreatedDate,
        IsActive = @IsActive
       
    WHERE 
        RoleId = @RoleId
END
GO

-- %% [markdown]
-- # [dbo].[sp_Update_StudentMaster]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Update_StudentMaster]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[sp_Update_StudentMaster]
     @StudentId int,
   
	@FirstName nvarchar(50),
	@LastName nvarchar(50),	 
	@Session nvarchar(50),
	@Email nvarchar(50),
	@ContactNo int,  
	@CreatedDate date,
	@IsActive bit,
	@IsDeleted bit
	
    
AS
BEGIN
    UPDATE tbl_StudentMaster
    SET 
        FirstName = @FirstName,
        LastName = @LastName,
		Session = @Session,
		Email = @Email,
		ContactNo = @ContactNo,
        CreatedDate = @CreatedDate,
        IsActive = @IsActive,
		IsDeleted = @IsDeleted
       
    WHERE 
        StudentId = @StudentId
END
GO

-- %% [markdown]
-- # [dbo].[sp_validate_IRCTCLogin]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_validate_IRCTCLogin]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_validate_IRCTCLogin]
 @fullName nvarchar(50),
 @emailId nvarchar(50),
    @decryptedPassword NVARCHAR(50)
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM tbl_IRCTC_Registration
        WHERE fullName = @fullName
        AND emailId = @emailId
        AND decryptedPassword = @decryptedPassword
    )
    BEGIN
        SELECT
            su.fullName,
            su.emailId
           
        FROM tbl_IRCTC_Registration su
        WHERE su.fullName = @fullName
        AND su.emailId = @emailId
        AND su.decryptedPassword = @decryptedPassword;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[sp_validate_LoginDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_validate_LoginDetails]    Script Date: 12/13/2023 12:18:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_validate_LoginDetails]
    @UserId INT,
    @Name NVARCHAR(50), -- Adjust the length based on your actual requirements
    @decryptedPassword NVARCHAR(50)
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM tbl_SignUp
        WHERE UserId = @UserId
        AND Name = @Name
        AND decryptedPassword = @decryptedPassword
    )
    BEGIN
        SELECT
            su.Id,
            su.Name,
            su.UserId
        FROM tbl_SignUp su
        WHERE su.UserId = @UserId
            AND su.Name = @Name
            AND su.decryptedPassword = @decryptedPassword;
    END
END;

GO

-- %% [markdown]
-- # [MVCWebAssessment]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [MVCWebAssessment] SET  READ_WRITE 
GO
